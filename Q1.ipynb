# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def imshow( image = None,title = "img", size = 20):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/(3*h)
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
def rotate_image(image = None, angle = 90):
  image_center = tuple(np.array(image.shape[1::-1]) / 2)
  rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
  result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
  return result

# %%
Original_image = cv2.imread('Original_image.jpg')
Height_org,Width_org = Original_image.shape[:-1]
imshow(Original_image)

# %%
Original_image.shape[:-1]
# Original_image.shape[0]
# Original_image.shape[1]
# tuple(np.array(Original_image.shape[1::-1]))
# Out:
# (976, 824)

# %%
transformed_image = cv2.imread('transformed_image.jpg')
imshow(transformed_image)

# %%
tmp = cv2.flip(Original_image,1)
# tmp = cv2.resize(tmp,None,fx=.5,fy=.5,interpolation = cv2.INTER_LINEAR)
# tmp = cv2.pyrDown(tmp)
# T = np.float32([[.45,0.1,Width_org/4],[0,.2,Height_org/4]])
T = np.float32([[.4,0,0],[0,.2,0]])
tmp = cv2.warpAffine(tmp, T, tmp.shape[1::-1])
T = np.float32([[1,.2,0],[0,1,0]])
tmp = cv2.warpAffine(tmp, T, tmp.shape[1::-1])
# rot_mat = cv2.getRotationMatrix2D(tuple(np.array(tmp.shape[1::-1])/2), -30, 1.0)
rot_mat = cv2.getRotationMatrix2D(tuple([0,0]), -30, 1.0)
tmp = cv2.warpAffine(tmp, rot_mat, tmp.shape[1::-1], flags=cv2.INTER_LINEAR)

T = np.float32([[1,0,550],[0,1,650]])
tmp = cv2.warpAffine(tmp, T, tmp.shape[1::-1])

q1 = tmp
imshow(tmp)

# %%
# T = np.float32([[1,0,-550],[0,1,-650]])
# tmp = cv2.warpAffine(transformed_image, T, transformed_image.shape[1::-1])

T = np.float32([[1,0,-550],[0,1,-650]])
tmp = cv2.warpAffine(q1, T, q1.shape[1::-1])

rot_mat = cv2.getRotationMatrix2D(tuple([0,0]), +30, 1.0)
tmp = cv2.warpAffine(tmp, rot_mat, tmp.shape[1::-1], flags=cv2.INTER_LINEAR)

T = np.float32([[1,-.2,0],[0,1,0]])
tmp = cv2.warpAffine(tmp, T, tmp.shape[1::-1])

T = np.float32([[2.5,0,0],[0,5,0]])
tmp = cv2.warpAffine(tmp, T, tmp.shape[1::-1])

tmp = cv2.flip(tmp,1)

imshow(tmp)
